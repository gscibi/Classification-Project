# %%
import pandas as pd

# %%
### The goal will be to predict the class
df = pd.read_csv('/Users/gianlucascibilia/Desktop/data/credit_customers.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %% [markdown]
# # EDA

# %%
#We are dealing with an imbalance dataset 
df['class'].value_counts()
# Out:
# class
# good    700
# bad     300
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 36))
fig.subplots_adjust(hspace=1.5)

ax1 = fig.add_subplot(8, 2, 1)
pd.crosstab(index=df['checking_status'], columns=df['class']).plot.bar(ax=ax1)
ax1.set_title('Checking Status')
ax1.set_xlabel('')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)

ax2 = fig.add_subplot(8, 2, 2)
pd.crosstab(index=df['credit_history'], columns=df['class']).plot.bar(ax=ax2)
ax2.set_title('Credit History')
ax2.set_xlabel('')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

ax3 = fig.add_subplot(8, 2, 3)
pd.crosstab(index=df['purpose'], columns=df['class']).plot.bar(ax=ax3)
ax3.set_title('Purpose')
ax3.set_xlabel('')
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=90)

ax4 = fig.add_subplot(8, 2, 4)
pd.crosstab(index=df['savings_status'], columns=df['class']).plot.bar(ax=ax4)
ax4.set_title('Savings Status')
ax4.set_xlabel('')
ax4.set_xticklabels(ax4.get_xticklabels(), rotation=90)

ax5 = fig.add_subplot(8, 2, 5)
pd.crosstab(index=df['employment'], columns=df['class']).plot.bar(ax=ax5)
ax5.set_title('Employment')
ax5.set_xlabel('')
ax5.set_xticklabels(ax5.get_xticklabels(), rotation=90)

ax6 = fig.add_subplot(8, 2, 6)
pd.crosstab(index=df['installment_commitment'], columns=df['class']).plot.bar(ax=ax6)
ax6.set_title('Installment Commitment')
ax6.set_xlabel('')
ax6.set_xticklabels(ax6.get_xticklabels(), rotation=90)

ax7 = fig.add_subplot(8, 2, 7)
pd.crosstab(index=df['personal_status'], columns=df['class']).plot.bar(ax=ax7)
ax7.set_title('Personal Status')
ax7.set_xlabel('')
ax7.set_xticklabels(ax7.get_xticklabels(), rotation=90)

ax8 = fig.add_subplot(8, 2, 8)
pd.crosstab(index=df['other_parties'], columns=df['class']).plot.bar(ax=ax8)
ax8.set_title('Other Parties')
ax8.set_xlabel('')
ax8.set_xticklabels(ax8.get_xticklabels(), rotation=90)

ax9 = fig.add_subplot(8, 2, 9)
pd.crosstab(index=df['residence_since'], columns=df['class']).plot.bar(ax=ax9)
ax9.set_title('Residence Since')
ax9.set_xlabel('')
ax9.set_xticklabels(ax9.get_xticklabels(), rotation=90)

ax10 = fig.add_subplot(8, 2, 10)
pd.crosstab(index=df['property_magnitude'], columns=df['class']).plot.bar(ax=ax10)
ax10.set_title('Property Magnitude')
ax10.set_xlabel('')
ax10.set_xticklabels(ax10.get_xticklabels(), rotation=45)

ax11 = fig.add_subplot(8, 2, 11)
pd.crosstab(index=df['other_payment_plans'], columns=df['class']).plot.bar(ax=ax11)
ax11.set_title('Other payment plans')
ax11.set_xlabel('')
ax11.set_xticklabels(ax11.get_xticklabels(), rotation=90)

ax12 = fig.add_subplot(8, 2, 12)
pd.crosstab(index=df['housing'], columns=df['class']).plot.bar(ax=ax12)
ax12.set_title('Housing')
ax12.set_xlabel('')
ax12.set_xticklabels(ax12.get_xticklabels(), rotation=90)

ax13 = fig.add_subplot(8, 2, 13)
pd.crosstab(index=df['existing_credits'], columns=df['class']).plot.bar(ax=ax13)
ax13.set_title('Housing')
ax13.set_xlabel('')
ax13.set_xticklabels(ax13.get_xticklabels(), rotation=90)

ax14 = fig.add_subplot(8, 2, 14)
pd.crosstab(index=df['job'], columns=df['class']).plot.bar(ax=ax14)
ax14.set_title('Housing')
ax14.set_xlabel('')
ax14.set_xticklabels(ax14.get_xticklabels(), rotation=90)

ax15 = fig.add_subplot(8, 2, 15)
pd.crosstab(index=df['num_dependents'], columns=df['class']).plot.bar(ax=ax15)
ax15.set_title('Housing')
ax15.set_xlabel('')
ax15.set_xticklabels(ax15.get_xticklabels(), rotation=90)

ax16 = fig.add_subplot(8, 2, 16)
pd.crosstab(index=df['own_telephone'], columns=df['class']).plot.bar(ax=ax16)
ax16.set_title('Housing')
ax16.set_xlabel('')
ax16.set_xticklabels(ax16.get_xticklabels(), rotation=90)

ax17 = fig.add_subplot(8, 2, 16)
pd.crosstab(index=df['foreign_worker'], columns=df['class']).plot.bar(ax=ax17)
ax17.set_title('Housing')
ax17.set_xlabel('')
ax17.set_xticklabels(ax17.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'no'), Text(1, 0, 'yes')]

# %%
#scatterplot
fig, ax = plt.subplots(figsize=(8,4))
(df.plot.scatter(x='class', y='credit_amount', alpha=.3, ax=ax, c='purple'))

#scatterplot
fig, ax = plt.subplots(figsize=(8,4))
(df.plot.scatter(x='class', y='age', alpha=.3, ax=ax, c='purple'))
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
#show the distribution
fix, ax = plt.subplots(figsize=(8,4))
_ =(df.groupby('class')[['credit_amount']].plot.hist(bins=30, alpha=.5, ax=ax, edgecolor='black'))
ax.legend(['bad','good'])

# %%
#show the distribution
fix, ax = plt.subplots(figsize=(8,4))
_ =(df.groupby('class')[['age']].plot.hist(bins=30, alpha=.5, ax=ax, edgecolor='black'))
ax.legend(['bad','good'])

# %% [markdown]
# # Feature Engineering

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
#use one hot encoder on the ones that are just categories, while label encoding for those that can be evaluated
df['class'] = df['class'].map({'good': 1, 'bad': 0})
df['checking_status'] = df['checking_status'].map({'no checking':0, '<0':1,'0<=X<200':2, '>=200':3 })
df['savings_status'] = df['savings_status'].map({'no known savings':0, '<100':1, '100<=X<500':2,'500<=X<1000':3, '>=1000':4 })
df['employment'] = df['employment'].map({'unemployed':0, '<1':1, '1<=X<4':2,'4<=X<7':3, '>=7':4 })
#df['job'] = df['employment'].map({'unemp/unskilled non res':0, 'unskilled resident':1, 'skilled':2,'high qualif/self emp/mgmt':3}) Unclear


#encoded_df = pd.get_dummies(df['personal_status', 'other_parties', 'purpose', 'property_magnitude', 'own_telephone', 'foreign_worker'])
# Out:
#      checking_status  duration                  credit_history
# 0                  1       6.0  critical/other existing credit  \
# 1                  2      48.0                   existing paid
# 2                  0      12.0  critical/other existing credit
# 3                  1      42.0                   existing paid
# 4                  1      24.0              delayed previously
# ..               ...       ...                             ...
# 995                0      12.0                   existing paid
# 996                1      30.0                   existing paid
# 997                0      12.0                   existing paid
# 998                1      45.0                   existing paid
# 999                2      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment
# 0               radio/tv         1169.0  no known savings         >=7  \
# ...
